# %%
import pandas as pd

# %%
data_montage = pd.read_excel('data/4.Ожидаемые поставки_Апрель2021.xlsx',skiprows=3)[:4980]

# %%
data_montage.head(10)
# Out:
#    Номер строки в заказе/релизе Код позиции ЕНС  \
# 0                             1  160.346.000041
# 1                             2  249.022.000011
# 2                             3  161.346.000136
# 3                             4  161.346.000137
# 4                             5  161.346.000132
# 5                             6  161.346.000133
# 6                             7  157.346.000121
# 7                             8  157.346.000122
# 8                             9  169.022.000118
# 9                            10  242.346.001015
#
#                             Наименование позиции ЕНС Единица измерения  \
# 0  Блок внутренний IDU Huawei RTN 910AF, 2хGE RJ4...             штука
# 1  Приемопередатчик оптический (eSFP, 1310нм, 1.2...             штука
# 2  Радиоблок внешний ODU Huawei RTN XMC-5D 18ГГц,...             штука
# 3  Радиоблок внешний ODU Huawei RTN XMC-5D 18ГГц,...             штука
# 4  Радиоблок внешний ODU Huawei RTN XMC-5D 18ГГц,...             штука
# ...

# %%
data_montage.shape
# Out:
# (4979, 16)

# %%
data_montage.fillna(0, inplace=True)

# %%
data_montage['Организация-получатель'].unique()
# Out:
# array(['101', '702', '304', 'К04'], dtype=object)

# %%
data_montage.isna().sum()
# Out:
# Номер строки в заказе/релизе          0
# Код позиции ЕНС                       0
# Наименование позиции ЕНС              0
# Единица измерения                     0
# Заказанное количество                 0
# Полученное количество                 0
# В пути                                0
# Организация-получатель                0
# Объём                                 0
# Общий объём                           0
# Дата исполнения заказа/договора     501
# м3                                    0
# Дата исполнения заказа/договора*    465
# Месяц                               465
# Год                                 465
# Дата поставки SWAP Эрикссон           0
# dtype: int64

# %%
data_montage.query("'Организация-получатель' == '304'")#.groupby(['Объём', 'Общий объём',]).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [105], line 1
# ----> 1 data_montage.query("'Организация-получатель' == '304'")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4466, in DataFrame.query(self, expr, inplace, **kwargs)
#    4463 res = self.eval(expr, **kwargs)
#    4465 try:
# -> 4466     result = self.loc[res]
#    4467 except ValueError:
# ...

# %%
data_304 = data_montage[ data_montage['Организация-получатель']  == '304' ].groupby(['Общий объём',"Код позиции ЕНС"]).sum()
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_3596\2700747899.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_304 = data_montage[ data_montage['Организация-получатель']  == '304' ].groupby(['Общий объём',"Код позиции ЕНС"]).sum()

# %%
data_304.head()
# Out:
#                              Номер строки в заказе/релизе  \
# Общий объём Код позиции ЕНС
# 0.000001    144.022.000693                             63
#             144.022.000785                             16
# 0.000002    144.022.000693                             13
# 0.000003    144.022.000693                              1
# 0.000004    144.022.000728                            155
#
#                              Заказанное количество  Полученное количество  \
# Общий объём Код позиции ЕНС
# 0.000001    144.022.000693                      18                     13
#             144.022.000785                       1                      0
# 0.000002    144.022.000693                      12                     10
# 0.000003    144.022.000693                       6                      3
# 0.000004    144.022.000728                      38                      8
#
#                              В пути        м3  Месяц      Год
# Общий объём Код позиции ЕНС
# ...

# %%
data_304.keys()
# Out:
# Index(['Номер строки в заказе/релизе', 'Заказанное количество',
#        'Полученное количество', 'В пути', 'м3', 'Месяц', 'Год'],
#       dtype='object')
