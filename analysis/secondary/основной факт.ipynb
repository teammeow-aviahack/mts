# %%
import pandas as pd

# %%
pd.read_excel('../../data/1.ОСНОВНОЙ Факт объемы_м3_2017_2022_по дням1.xlsx', skiprows=1, sheet_name=4)
# Out:
#       неделя                 дата   МСК 101  МСК 107          СЗ  \
# 0        1.0  2021-01-01 00:00:00  10118.75      0.0  7110.04116
# 1        1.0  2021-01-02 00:00:00  10118.75      0.0  7110.04116
# 2        2.0  2021-01-03 00:00:00  10118.75      0.0  7110.04116
# 3        2.0  2021-01-04 00:00:00  10118.75      0.0  7110.04116
# 4        2.0  2021-01-05 00:00:00  10118.75      0.0  7110.04116
# ...      ...                  ...       ...      ...         ...
# 3892     NaN                  NaN       NaN      NaN         NaN
# 3893     NaN                  NaN       NaN      NaN         NaN
# 3894     NaN                  NaN       NaN      NaN         NaN
# 3895     NaN                  NaN       NaN      NaN         NaN
# 3896     NaN                  NaN       NaN      NaN         NaN
#
#       МСК Демонтаж    Урал   Всего Хранение  Unnamed: 8  МСК 101.1  ...  \
# 0              0.0  2869.1      20097.89116         NaN       0.18  ...
# ...
