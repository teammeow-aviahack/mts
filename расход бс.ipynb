# %%
import pandas as pd

# %%
data_montage = pd.read_excel('data/2.Факт расход в монтаж БС штуки 2021.xlsx', sheet_name=2)[:466]

# %%
data_montage.head(10)
# Out:
#       год неделя        Расход  МРМосква  МРСеверозапад  МРУрал  Общий итог  \
# 0  2017.0     40            БС      37.0           22.0     1.0       245.0
# 1  2017.0     40  модули/блоки     120.0           44.0     NaN       290.0
# 2  2017.0     41            БС      11.0            NaN    13.0       109.0
# 3  2017.0     41  модули/блоки      40.0            NaN     1.0        93.0
# 4  2017.0     42            БС       NaN           21.0    25.0        91.0
# 5  2017.0     42  модули/блоки       NaN           55.0     8.0        81.0
# 6  2017.0     43            БС      11.0           27.0    15.0       192.0
# 7  2017.0     43  модули/блоки      59.0          107.0     1.0       198.0
# 8  2017.0     44            БС      14.0           14.0    23.0       493.0
# 9  2017.0     44  модули/блоки     141.0           23.0     3.0       252.0
#
#    Месяц
# 0   10.0
# 1   10.0
# 2   10.0
# 3   10.0
# 4   10.0
# 5   10.0
# 6   10.0
# 7   10.0
# 8   10.0
# 9   10.0

# %%
data_montage.shape
# Out:
# (466, 8)

# %%
data_montage.fillna(0, inplace=True)

# %%
data_montage['год'].unique()
# Out:
# array([2017., 2018., 2019., 2020., 2021., 2022.])

# %%
data_montage.isna().sum()
# Out:
# год              0
# неделя           0
# Расход           0
# МРМосква         0
# МРСеверозапад    0
# МРУрал           0
# Общий итог       0
# Месяц            0
# dtype: int64

# %%
data_montage.query("год == 2021").groupby(['год', 'Месяц', 'Расход']).sum()
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_3596\55942655.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_montage.query("год == 2021").groupby(['год', 'Месяц', 'Расход']).sum()
#                            МРМосква  МРСеверозапад  МРУрал  Общий итог
# год    Месяц Расход
# 2021.0 1.0   БС                43.0           54.0    64.0       711.0
#              модули/блоки     121.0           80.0   264.0      1505.0
#        2.0   БС               135.0          300.0   145.0      1609.0
#              модули/блоки     201.0          493.0   261.0      2413.0
#        3.0   БС               176.0          238.0    86.0      1752.0
#              модули/блоки     292.0          560.0   205.0      3371.0
#        4.0   БС               175.0          244.0    65.0      1871.0
# ...
